# %%
import numpy as np
import random
from operator import itemgetter
from random import randint

# %% [markdown]
# <h2>Funciones de prueba</h2>

# %%
def calculoCM(n):
    k = (n*(n**2 + 1))/2
    return k

# %%
def conteoExitos(cuadrado = np.array([])):

    n = int(len(cuadrado)**0.5)

    k = calculoCM(n)

    matriz = cuadrado.reshape((n,n))

    sumatoria_columnas = np.sum(matriz, axis=0)
    sumatoria_filas = np.sum(matriz, axis=1)
    diagonal_principal = np.trace(matriz)
    diagonal_secundaria = np.trace(matriz[::-1])

    valores = np.concatenate((sumatoria_columnas, sumatoria_filas, np.array([diagonal_principal, diagonal_secundaria])), axis = 0)

    numExitos = 0

    for i in valores:
        if k == i:
            numExitos+=1

    return numExitos

# %%
def errorMinimo(cuadrado = np.array([])):

    n = int(len(cuadrado)**0.5)

    k = calculoCM(n)

    matriz = cuadrado.reshape((n,n))

    sumatoria_columnas = np.sum(matriz, axis=0)
    sumatoria_filas = np.sum(matriz, axis=1)
    diagonal_principal = np.trace(matriz)
    diagonal_secundaria = np.trace(matriz[::-1])

    valores = np.concatenate((sumatoria_columnas, sumatoria_filas, np.array([diagonal_principal, diagonal_secundaria])), axis = 0)

    error = 0

    for i in valores:
        error += np.abs((k-i))

    return error

# %%
# Generar un np.array de valores del 1 al 9 en orden
arr = np.arange(1, 10)

# Permutar aleatoriamente los valores
np.random.shuffle(arr)

print(arr.reshape((3,3)))

print(conteoExitos(cuadrado = arr))
print(errorMinimo(cuadrado = arr))
# Out:
# [[5 2 4]
#  [3 8 9]
#  [7 1 6]]
# 1
# 26.0

# %% [markdown]
# <h2>Estrategia de selección de padres</h2>

# %% [markdown]
# <h3>La ruleta</h3>

# %%
def seleccion_ruleta(poblacion, fitness):
    # Normalizar el fitness
    probabilidad = fitness / np.sum(fitness)
    probAcumulada = np.cumsum(probabilidad)
    r = np.random.uniform(0, 1, size=len(poblacion))
    # Seleccionar los padres
    padres = list()
    for i in range(len(poblacion)):
        index = np.where(probAcumulada >= r[i])[0][0]
        padres.append(index)
        
    return padres

# %% [markdown]
# <h2>Operador de cruza (PMX)</h2>

# %%
def pmx(parent1, parent2):
    size = len(parent1)
    child1 = np.zeros(size, dtype=np.uint32)
    child2 = np.zeros(size, dtype=np.uint32)

    # Seleccionar dos puntos aleatorios
    point1 = np.random.randint(0, size)
    point2 = np.random.randint(0, size - 1)
    if point2 >= point1:
        point2 += 1

    # Copiar los segmentos seleccionados de los padres a los hijos
    child1[point1:point2] = parent1[point1:point2]
    child2[point1:point2] = parent2[point1:point2]

    # Completar los hijos con los valores faltantes
    for i in range(size):
        if not parent2[i] in child1:
            for j in range(size):
                if child1[j] == 0:
                    child1[j] = parent2[i]
                    break
        if not parent1[i] in child2:
            for j in range(size):
                if child2[j] == 0:
                    child2[j] = parent1[i]
                    break

    return child1, child2

# %% [markdown]
# <h2>Operador de mutación</h2>

# %%
def mutacion(poblacion, porcMuta, fPrueba):  

  cromosomas = [sublista[0] for sublista in poblacion]

  for i in range(len(cromosomas)):
    if porcMuta >= np.random.uniform(0,1): 
      
      inicio = random.randint(0, len(cromosomas[i])-2)
      final = random.randint(inicio+1, len(cromosomas[i])-1)

      aux = cromosomas[i][inicio]
      cromosomas[i][inicio] = cromosomas[i][final]
      cromosomas[i][final] = aux


  out = list()

  for i in cromosomas:
      if fPrueba == 0:
          fx = conteoExitos(i)
      elif fPrueba == 1:
          fx = errorMinimo(i)

      out.append([i, fx])

  return out

# %% [markdown]
# <h2>Estructura del algoritmo genetico</h2>

# %% [markdown]
# <h3>Inicialización la población</h3>

# %%
def poblacionInicial(tam, n, mode):

  if mode == 0:
    function = conteoExitos
  elif mode == 1:
    function = errorMinimo

  poblacion = list()
  for i in range(0, tam-1): 
    arr = np.arange(1, (n**2)+1)
    np.random.shuffle(arr)
   
    fx = round(function(arr),4)
    poblacion.append([arr, fx])
    
  return poblacion

# %%
poblacionInicial(10,3,1)
# Out:
# [[array([3, 7, 2, 9, 4, 1, 8, 6, 5]), 26.0],
#  [array([7, 3, 5, 8, 4, 2, 9, 6, 1]), 26.0],
#  [array([5, 8, 4, 2, 9, 6, 3, 7, 1]), 27.0],
#  [array([8, 1, 9, 4, 5, 7, 2, 6, 3]), 18.0],
#  [array([7, 4, 9, 3, 6, 8, 2, 5, 1]), 23.0],
#  [array([1, 8, 7, 3, 2, 4, 6, 5, 9]), 25.0],
#  [array([7, 8, 5, 1, 4, 2, 6, 3, 9]), 23.0],
#  [array([3, 6, 5, 9, 7, 2, 1, 4, 8]), 15.0],
#  [array([4, 5, 6, 8, 9, 7, 2, 3, 1]), 25.0]]

# %%
poblacionInicial(10,3,1)
# Out:
# [[array([1, 6, 2, 9, 5, 4, 3, 7, 8]), 24.0],
#  [array([1, 3, 9, 6, 4, 2, 7, 8, 5]), 22.0],
#  [array([8, 2, 5, 3, 1, 6, 9, 4, 7]), 27.0],
#  [array([4, 9, 5, 1, 6, 8, 3, 2, 7]), 23.0],
#  [array([9, 4, 5, 3, 7, 1, 8, 2, 6]), 30.0],
#  [array([9, 1, 3, 4, 5, 2, 8, 6, 7]), 31.0],
#  [array([5, 1, 8, 9, 7, 4, 2, 6, 3]), 14.0],
#  [array([3, 1, 6, 2, 7, 9, 8, 5, 4]), 25.0],
#  [array([4, 5, 6, 7, 2, 1, 3, 8, 9]), 16.0]]

# %%
def seleccionPadres(poblacion):
    padres = [sublista[0] for sublista in poblacion]
    fitness = [sublista[1] for sublista in poblacion]

    return seleccion_ruleta(padres, fitness)

# %%
a = poblacionInicial(10,3,1)
b = seleccionPadres(a)
print(a)
print(b)
# Out:
# [[array([1, 4, 7, 8, 2, 9, 3, 6, 5]), 30.0], [array([6, 5, 4, 3, 1, 8, 9, 2, 7]), 22.0], [array([3, 4, 7, 9, 1, 6, 5, 2, 8]), 23.0], [array([8, 3, 6, 2, 9, 4, 1, 7, 5]), 20.0], [array([3, 2, 4, 9, 7, 6, 5, 1, 8]), 28.0], [array([1, 4, 5, 8, 7, 9, 3, 6, 2]), 29.0], [array([2, 5, 8, 7, 4, 9, 3, 6, 1]), 24.0], [array([1, 4, 6, 9, 2, 3, 8, 7, 5]), 24.0], [array([9, 8, 2, 5, 7, 4, 3, 6, 1]), 31.0]]
# [5, 6, 6, 5, 5, 3, 6, 1, 5]

# %% [markdown]
# <h3>Cruza de padres con cierta probabilidad</h3>

# %%
def cruza(padres, indices, prob_cruza, fPrueba):

    cromosomas = [sublista[0] for sublista in padres]

    hijos = list()
    i = 0

    while i < len(cromosomas):

        try:
            padre1 = cromosomas[indices[i]]
            padre2 = cromosomas[indices[i+1]]

            if random.uniform(0,1) >= prob_cruza:
                h1, h2 = pmx(padre1, padre2)
                hijos.append(h1)
                hijos.append(h2)
                        
            
        except:
            pass
        
        i+=2


    if len(hijos) == 0:
        return []
    else:

        out = list()

        for i in hijos:
            if fPrueba == 0:
                
                fx = conteoExitos(i)
            elif fPrueba == 1:
                fx = errorMinimo(i)

            out.append([i, fx])

        return out

# %% [markdown]
# <h2>Implementación del algoritmo génetico</h2>

# %%
def algoritmoGenetico(tamPoblacion, n, porcCruza, porcMuta, funcionPrueba):
  padres = poblacionInicial(tamPoblacion, n,funcionPrueba)

  mejores = list()
  peores = list()
  promedio = list()

  fit = 1000000000
  contadorGeneraciones = 0
  gen = 0

  # Inicialización de la memoria
  memoria = set()

  while True:
    gen=gen+1
    print("--------------------------------")
    print("No. de Generacion=")
    print(gen)
    print(f'Contador de generaciones con el mismo mejor individio {contadorGeneraciones}')
    print(f'Mejor solución actual: {fit}')

    indices = seleccionPadres(padres)
    hijos = cruza(padres,indices, porcCruza, funcionPrueba)

    hijos = mutacion(hijos, porcMuta, funcionPrueba)
    nuevaPoblacion = padres + hijos
  
    if funcionPrueba == 0:
      sobrevivientes = sorted(nuevaPoblacion, key=itemgetter(1), reverse=True)   
    elif funcionPrueba == 1:
      sobrevivientes = sorted(nuevaPoblacion, key=itemgetter(1)) 

    padres = sobrevivientes[0: tamPoblacion]

    prom = 0
    for p in padres:
      prom += p[1]
    promedio.append(prom/len(padres))

    mejores.append(padres[0][1])
    peores.append(padres[-1][1])

    fitAnterior = fit

    fit = padres[0][1]
    print(f'Mejor solución actual: {fit}')


    print ("mejor solucion", padres[0])

    if fitAnterior == fit:
      contadorGeneraciones += 1
      if contadorGeneraciones > 20:

        tamPoblacionEstancada = int(tamPoblacion*0.2)

        PoblacionEstancada = padres[:tamPoblacionEstancada]

        poblacionAleatoria = poblacionInicial(int(tamPoblacion*0.8), n,funcionPrueba)
        
        padres = PoblacionEstancada+poblacionAleatoria
    else:
      contadorGeneraciones = 0
        
    

    if funcionPrueba == 0 and fit == ((n*2)+2):
      break
    elif funcionPrueba == 1 and fit == 0:
      break
    else:
      pass

  return mejores, peores, promedio, gen

# %%
algoritmoGenetico(5000,5,0.7,0.2,1)
# Out:
# --------------------------------
# No. de Generacion=
# 1
# Contador de generaciones con el mismo mejor individio 0
# Mejor solución actual: 1000000000
# Mejor solución actual: 47.0
# mejor solucion [array([ 7,  5, 19, 16, 22, 17, 25, 11,  8,  2, 14, 12,  3, 23, 10,  1,  9,
#        13, 20, 24, 21,  6, 18,  4, 15]), 47.0]
# --------------------------------
# No. de Generacion=
# 2
# Contador de generaciones con el mismo mejor individio 0
# Mejor solución actual: 47.0
# Mejor solución actual: 47.0
# mejor solucion [array([ 7,  5, 19, 16, 22, 17, 25, 11,  8,  2, 14, 12,  3, 23, 10,  1,  9,
#        13, 20, 24, 21,  6, 18,  4, 15]), 47.0]
# --------------------------------
# No. de Generacion=
# 3
# Contador de generaciones con el mismo mejor individio 1
# Mejor solución actual: 47.0
# Mejor solución actual: 47.0
# mejor solucion [array([ 7,  5, 19, 16, 22, 17, 25, 11,  8,  2, 14, 12,  3, 23, 10,  1,  9,
#        13, 20, 24, 21,  6, 18,  4, 15]), 47.0]
# --------------------------------
# No. de Generacion=
# 4
# Contador de generaciones con el mismo mejor individio 2
# Mejor solución actual: 47.0
# Mejor solución actual: 47.0
# mejor solucion [array([ 7,  5, 19, 16, 22, 17, 25, 11,  8,  2, 14, 12,  3, 23, 10,  1,  9,
#        13, 20, 24, 21,  6, 18,  4, 15]), 47.0]
# --------------------------------
# No. de Generacion=
# 5
# Contador de generaciones con el mismo mejor individio 3
# Mejor solución actual: 47.0
# Mejor solución actual: 47.0
# mejor solucion [array([ 7,  5, 19, 16, 22, 17, 25, 11,  8,  2, 14, 12,  3, 23, 10,  1,  9,
#        13, 20, 24, 21,  6, 18,  4, 15]), 47.0]
# --------------------------------
# No. de Generacion=
# 6
# Contador de generaciones con el mismo mejor individio 4
# Mejor solución actual: 47.0
# Mejor solución actual: 47.0
# mejor solucion [array([ 7,  5, 19, 16, 22, 17, 25, 11,  8,  2, 14, 12,  3, 23, 10,  1,  9,
#        13, 20, 24, 21,  6, 18,  4, 15]), 47.0]
# --------------------------------
# No. de Generacion=
# 7
# Contador de generaciones con el mismo mejor individio 5
# Mejor solución actual: 47.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 8
# Contador de generaciones con el mismo mejor individio 0
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 9
# Contador de generaciones con el mismo mejor individio 1
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 10
# Contador de generaciones con el mismo mejor individio 2
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 11
# Contador de generaciones con el mismo mejor individio 3
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 12
# Contador de generaciones con el mismo mejor individio 4
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 13
# Contador de generaciones con el mismo mejor individio 5
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 14
# Contador de generaciones con el mismo mejor individio 6
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 15
# Contador de generaciones con el mismo mejor individio 7
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 16
# Contador de generaciones con el mismo mejor individio 8
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 17
# Contador de generaciones con el mismo mejor individio 9
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 18
# Contador de generaciones con el mismo mejor individio 10
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 19
# Contador de generaciones con el mismo mejor individio 11
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 20
# Contador de generaciones con el mismo mejor individio 12
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 21
# Contador de generaciones con el mismo mejor individio 13
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 22
# Contador de generaciones con el mismo mejor individio 14
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 23
# Contador de generaciones con el mismo mejor individio 15
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 24
# Contador de generaciones con el mismo mejor individio 16
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 25
# Contador de generaciones con el mismo mejor individio 17
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 26
# Contador de generaciones con el mismo mejor individio 18
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 27
# Contador de generaciones con el mismo mejor individio 19
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 28
# Contador de generaciones con el mismo mejor individio 20
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 29
# Contador de generaciones con el mismo mejor individio 21
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 30
# Contador de generaciones con el mismo mejor individio 22
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 31
# Contador de generaciones con el mismo mejor individio 23
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 32
# Contador de generaciones con el mismo mejor individio 24
# Mejor solución actual: 40.0
# Mejor solución actual: 40.0
# mejor solucion [array([ 8, 11, 22,  9, 18, 16, 17, 13, 14,  2, 24,  4, 19,  5, 20,  6, 12,
#         1, 23, 21,  7, 25, 10, 15,  3], dtype=uint32), 40.0]
# --------------------------------
# No. de Generacion=
# 33
# Contador de generaciones con el mismo mejor individio 25
# Mejor solución actual: 40.0
# Mejor solución actual: 39.0
# mejor solucion [array([19, 18, 12,  4, 13, 10,  1, 15, 21, 22, 17, 14,  6, 20,  9, 16, 23,
#         7, 11,  8,  2,  3, 24,  5, 25], dtype=uint32), 39.0]
# --------------------------------
# No. de Generacion=
# 34
# Contador de generaciones con el mismo mejor individio 0
# Mejor solución actual: 39.0
# Mejor solución actual: 39.0
# mejor solucion [array([19, 18, 12,  4, 13, 10,  1, 15, 21, 22, 17, 14,  6, 20,  9, 16, 23,
#         7, 11,  8,  2,  3, 24,  5, 25], dtype=uint32), 39.0]
# --------------------------------
# No. de Generacion=
# 35
# Contador de generaciones con el mismo mejor individio 1
# Mejor solución actual: 39.0
# Mejor solución actual: 39.0
# mejor solucion [array([19, 18, 12,  4, 13, 10,  1, 15, 21, 22, 17, 14,  6, 20,  9, 16, 23,
#         7, 11,  8,  2,  3, 24,  5, 25], dtype=uint32), 39.0]
# --------------------------------
# No. de Generacion=
# 36
# Contador de generaciones con el mismo mejor individio 2
# Mejor solución actual: 39.0
# Mejor solución actual: 39.0
# mejor solucion [array([19, 18, 12,  4, 13, 10,  1, 15, 21, 22, 17, 14,  6, 20,  9, 16, 23,
#         7, 11,  8,  2,  3, 24,  5, 25], dtype=uint32), 39.0]
# --------------------------------
# No. de Generacion=
# 37
# Contador de generaciones con el mismo mejor individio 3
# Mejor solución actual: 39.0
# Mejor solución actual: 39.0
# mejor solucion [array([19, 18, 12,  4, 13, 10,  1, 15, 21, 22, 17, 14,  6, 20,  9, 16, 23,
#         7, 11,  8,  2,  3, 24,  5, 25], dtype=uint32), 39.0]
# --------------------------------
# No. de Generacion=
# 38
# Contador de generaciones con el mismo mejor individio 4
# Mejor solución actual: 39.0
# Mejor solución actual: 39.0
# mejor solucion [array([19, 18, 12,  4, 13, 10,  1, 15, 21, 22, 17, 14,  6, 20,  9, 16, 23,
#         7, 11,  8,  2,  3, 24,  5, 25], dtype=uint32), 39.0]
# --------------------------------
# No. de Generacion=
# 39
# Contador de generaciones con el mismo mejor individio 5
# Mejor solución actual: 39.0
# Mejor solución actual: 39.0
# mejor solucion [array([19, 18, 12,  4, 13, 10,  1, 15, 21, 22, 17, 14,  6, 20,  9, 16, 23,
#         7, 11,  8,  2,  3, 24,  5, 25], dtype=uint32), 39.0]
# --------------------------------
# No. de Generacion=
# 40
# Contador de generaciones con el mismo mejor individio 6
# Mejor solución actual: 39.0
# Mejor solución actual: 39.0
# mejor solucion [array([19, 18, 12,  4, 13, 10,  1, 15, 21, 22, 17, 14,  6, 20,  9, 16, 23,
#         7, 11,  8,  2,  3, 24,  5, 25], dtype=uint32), 39.0]
# --------------------------------
# No. de Generacion=
# 41
# Contador de generaciones con el mismo mejor individio 7
# Mejor solución actual: 39.0
# Mejor solución actual: 39.0
# mejor solucion [array([19, 18, 12,  4, 13, 10,  1, 15, 21, 22, 17, 14,  6, 20,  9, 16, 23,
#         7, 11,  8,  2,  3, 24,  5, 25], dtype=uint32), 39.0]
# --------------------------------
# No. de Generacion=
# 42
# Contador de generaciones con el mismo mejor individio 8
# Mejor solución actual: 39.0
# Mejor solución actual: 39.0
# mejor solucion [array([19, 18, 12,  4, 13, 10,  1, 15, 21, 22, 17, 14,  6, 20,  9, 16, 23,
#         7, 11,  8,  2,  3, 24,  5, 25], dtype=uint32), 39.0]
# --------------------------------
# No. de Generacion=
# 43
# Contador de generaciones con el mismo mejor individio 9
# Mejor solución actual: 39.0
# Mejor solución actual: 39.0
# mejor solucion [array([19, 18, 12,  4, 13, 10,  1, 15, 21, 22, 17, 14,  6, 20,  9, 16, 23,
#         7, 11,  8,  2,  3, 24,  5, 25], dtype=uint32), 39.0]
# --------------------------------
# No. de Generacion=
# 44
# Contador de generaciones con el mismo mejor individio 10
# Mejor solución actual: 39.0
# Mejor solución actual: 39.0
# mejor solucion [array([19, 18, 12,  4, 13, 10,  1, 15, 21, 22, 17, 14,  6, 20,  9, 16, 23,
#         7, 11,  8,  2,  3, 24,  5, 25], dtype=uint32), 39.0]
# --------------------------------
# No. de Generacion=
# 45
# Contador de generaciones con el mismo mejor individio 11
# Mejor solución actual: 39.0
# Mejor solución actual: 37.0
# mejor solucion [array([ 3,  7, 23, 18, 15, 25,  5, 13,  9, 10, 19, 17,  6,  4, 21,  2, 22,
#        14, 24,  1, 11, 12, 16,  8, 20], dtype=uint32), 37.0]
# --------------------------------
# No. de Generacion=
# 46
# Contador de generaciones con el mismo mejor individio 0
# Mejor solución actual: 37.0
# Mejor solución actual: 37.0
# mejor solucion [array([ 3,  7, 23, 18, 15, 25,  5, 13,  9, 10, 19, 17,  6,  4, 21,  2, 22,
#        14, 24,  1, 11, 12, 16,  8, 20], dtype=uint32), 37.0]
# --------------------------------
# No. de Generacion=
# 47
# Contador de generaciones con el mismo mejor individio 1
# Mejor solución actual: 37.0
# Mejor solución actual: 37.0
# mejor solucion [array([ 3,  7, 23, 18, 15, 25,  5, 13,  9, 10, 19, 17,  6,  4, 21,  2, 22,
#        14, 24,  1, 11, 12, 16,  8, 20], dtype=uint32), 37.0]
# --------------------------------
# No. de Generacion=
# 48
# Contador de generaciones con el mismo mejor individio 2
# Mejor solución actual: 37.0
# Mejor solución actual: 37.0
# mejor solucion [array([ 3,  7, 23, 18, 15, 25,  5, 13,  9, 10, 19, 17,  6,  4, 21,  2, 22,
#        14, 24,  1, 11, 12, 16,  8, 20], dtype=uint32), 37.0]
# --------------------------------
# No. de Generacion=
# 49
# Contador de generaciones con el mismo mejor individio 3
# Mejor solución actual: 37.0
# Mejor solución actual: 37.0
# mejor solucion [array([ 3,  7, 23, 18, 15, 25,  5, 13,  9, 10, 19, 17,  6,  4, 21,  2, 22,
#        14, 24,  1, 11, 12, 16,  8, 20], dtype=uint32), 37.0]
# --------------------------------
# No. de Generacion=
# 50
# Contador de generaciones con el mismo mejor individio 4
# Mejor solución actual: 37.0
# Mejor solución actual: 37.0
# mejor solucion [array([ 3,  7, 23, 18, 15, 25,  5, 13,  9, 10, 19, 17,  6,  4, 21,  2, 22,
#        14, 24,  1, 11, 12, 16,  8, 20], dtype=uint32), 37.0]
# --------------------------------
# No. de Generacion=
# 51
# Contador de generaciones con el mismo mejor individio 5
# Mejor solución actual: 37.0
# Mejor solución actual: 37.0
# mejor solucion [array([ 3,  7, 23, 18, 15, 25,  5, 13,  9, 10, 19, 17,  6,  4, 21,  2, 22,
#        14, 24,  1, 11, 12, 16,  8, 20], dtype=uint32), 37.0]
# --------------------------------
# No. de Generacion=
# 52
# Contador de generaciones con el mismo mejor individio 6
# Mejor solución actual: 37.0
# Mejor solución actual: 34.0
# mejor solucion [array([19,  3,  4, 22, 12, 25,  6, 15,  5, 13,  8,  9, 17, 21, 18, 10, 24,
#        16, 11,  2,  1, 23, 14,  7, 20], dtype=uint32), 34.0]
# --------------------------------
# No. de Generacion=
# 53
# Contador de generaciones con el mismo mejor individio 0
# Mejor solución actual: 34.0
# Mejor solución actual: 29.0
# mejor solucion [array([18,  1, 14, 16, 13, 17,  5, 19, 11, 15,  6, 20,  8,  7, 25,  2, 10,
#        21, 24,  9, 23, 22,  4, 12,  3], dtype=uint32), 29.0]
# --------------------------------
# No. de Generacion=
# 54
# Contador de generaciones con el mismo mejor individio 0
# Mejor solución actual: 29.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 55
# Contador de generaciones con el mismo mejor individio 0
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 56
# Contador de generaciones con el mismo mejor individio 1
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 57
# Contador de generaciones con el mismo mejor individio 2
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 58
# Contador de generaciones con el mismo mejor individio 3
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 59
# Contador de generaciones con el mismo mejor individio 4
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 60
# Contador de generaciones con el mismo mejor individio 5
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 61
# Contador de generaciones con el mismo mejor individio 6
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 62
# Contador de generaciones con el mismo mejor individio 7
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 63
# Contador de generaciones con el mismo mejor individio 8
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 64
# Contador de generaciones con el mismo mejor individio 9
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 65
# Contador de generaciones con el mismo mejor individio 10
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 66
# Contador de generaciones con el mismo mejor individio 11
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 67
# Contador de generaciones con el mismo mejor individio 12
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 68
# Contador de generaciones con el mismo mejor individio 13
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 69
# Contador de generaciones con el mismo mejor individio 14
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 70
# Contador de generaciones con el mismo mejor individio 15
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 71
# Contador de generaciones con el mismo mejor individio 16
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 72
# Contador de generaciones con el mismo mejor individio 17
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 73
# Contador de generaciones con el mismo mejor individio 18
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 74
# Contador de generaciones con el mismo mejor individio 19
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 75
# Contador de generaciones con el mismo mejor individio 20
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 76
# Contador de generaciones con el mismo mejor individio 21
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 77
# Contador de generaciones con el mismo mejor individio 22
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 78
# Contador de generaciones con el mismo mejor individio 23
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 79
# Contador de generaciones con el mismo mejor individio 24
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 80
# Contador de generaciones con el mismo mejor individio 25
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 81
# Contador de generaciones con el mismo mejor individio 26
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 82
# Contador de generaciones con el mismo mejor individio 27
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 83
# Contador de generaciones con el mismo mejor individio 28
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 84
# Contador de generaciones con el mismo mejor individio 29
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 85
# Contador de generaciones con el mismo mejor individio 30
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 86
# Contador de generaciones con el mismo mejor individio 31
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 87
# Contador de generaciones con el mismo mejor individio 32
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 88
# Contador de generaciones con el mismo mejor individio 33
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 89
# Contador de generaciones con el mismo mejor individio 34
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 90
# Contador de generaciones con el mismo mejor individio 35
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 91
# Contador de generaciones con el mismo mejor individio 36
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 92
# Contador de generaciones con el mismo mejor individio 37
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 93
# Contador de generaciones con el mismo mejor individio 38
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 94
# Contador de generaciones con el mismo mejor individio 39
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 95
# Contador de generaciones con el mismo mejor individio 40
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 96
# Contador de generaciones con el mismo mejor individio 41
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 97
# Contador de generaciones con el mismo mejor individio 42
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 98
# Contador de generaciones con el mismo mejor individio 43
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 99
# Contador de generaciones con el mismo mejor individio 44
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 100
# Contador de generaciones con el mismo mejor individio 45
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 101
# Contador de generaciones con el mismo mejor individio 46
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 102
# Contador de generaciones con el mismo mejor individio 47
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 103
# Contador de generaciones con el mismo mejor individio 48
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 104
# Contador de generaciones con el mismo mejor individio 49
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 105
# Contador de generaciones con el mismo mejor individio 50
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 106
# Contador de generaciones con el mismo mejor individio 51
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 107
# Contador de generaciones con el mismo mejor individio 52
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 108
# Contador de generaciones con el mismo mejor individio 53
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 109
# Contador de generaciones con el mismo mejor individio 54
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 110
# Contador de generaciones con el mismo mejor individio 55
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 111
# Contador de generaciones con el mismo mejor individio 56
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 112
# Contador de generaciones con el mismo mejor individio 57
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 113
# Contador de generaciones con el mismo mejor individio 58
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 114
# Contador de generaciones con el mismo mejor individio 59
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 115
# Contador de generaciones con el mismo mejor individio 60
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 116
# Contador de generaciones con el mismo mejor individio 61
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 117
# Contador de generaciones con el mismo mejor individio 62
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 118
# Contador de generaciones con el mismo mejor individio 63
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 119
# Contador de generaciones con el mismo mejor individio 64
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 120
# Contador de generaciones con el mismo mejor individio 65
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 121
# Contador de generaciones con el mismo mejor individio 66
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 122
# Contador de generaciones con el mismo mejor individio 67
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 123
# Contador de generaciones con el mismo mejor individio 68
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 124
# Contador de generaciones con el mismo mejor individio 69
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 125
# Contador de generaciones con el mismo mejor individio 70
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 126
# Contador de generaciones con el mismo mejor individio 71
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 127
# Contador de generaciones con el mismo mejor individio 72
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 128
# Contador de generaciones con el mismo mejor individio 73
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 129
# Contador de generaciones con el mismo mejor individio 74
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 130
# Contador de generaciones con el mismo mejor individio 75
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 131
# Contador de generaciones con el mismo mejor individio 76
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 132
# Contador de generaciones con el mismo mejor individio 77
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 133
# Contador de generaciones con el mismo mejor individio 78
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 134
# Contador de generaciones con el mismo mejor individio 79
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 135
# Contador de generaciones con el mismo mejor individio 80
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 136
# Contador de generaciones con el mismo mejor individio 81
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 137
# Contador de generaciones con el mismo mejor individio 82
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 138
# Contador de generaciones con el mismo mejor individio 83
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 139
# Contador de generaciones con el mismo mejor individio 84
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 140
# Contador de generaciones con el mismo mejor individio 85
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 141
# Contador de generaciones con el mismo mejor individio 86
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 142
# Contador de generaciones con el mismo mejor individio 87
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 143
# Contador de generaciones con el mismo mejor individio 88
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 144
# Contador de generaciones con el mismo mejor individio 89
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 145
# Contador de generaciones con el mismo mejor individio 90
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 146
# Contador de generaciones con el mismo mejor individio 91
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 147
# Contador de generaciones con el mismo mejor individio 92
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 148
# Contador de generaciones con el mismo mejor individio 93
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 149
# Contador de generaciones con el mismo mejor individio 94
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 150
# Contador de generaciones con el mismo mejor individio 95
# Mejor solución actual: 23.0
# Mejor solución actual: 23.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 18, 16, 12,  6, 13, 17, 11,  2, 25,  5,  9, 10,
#        21, 23,  1, 22,  8, 15,  7, 19], dtype=uint32), 23.0]
# --------------------------------
# No. de Generacion=
# 151
# ...
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1184
# Contador de generaciones con el mismo mejor individio 488
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1185
# Contador de generaciones con el mismo mejor individio 489
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1186
# Contador de generaciones con el mismo mejor individio 490
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1187
# Contador de generaciones con el mismo mejor individio 491
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1188
# Contador de generaciones con el mismo mejor individio 492
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1189
# Contador de generaciones con el mismo mejor individio 493
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1190
# Contador de generaciones con el mismo mejor individio 494
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1191
# Contador de generaciones con el mismo mejor individio 495
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1192
# Contador de generaciones con el mismo mejor individio 496
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1193
# Contador de generaciones con el mismo mejor individio 497
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1194
# Contador de generaciones con el mismo mejor individio 498
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1195
# Contador de generaciones con el mismo mejor individio 499
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1196
# Contador de generaciones con el mismo mejor individio 500
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1197
# Contador de generaciones con el mismo mejor individio 501
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1198
# Contador de generaciones con el mismo mejor individio 502
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1199
# Contador de generaciones con el mismo mejor individio 503
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1200
# Contador de generaciones con el mismo mejor individio 504
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1201
# Contador de generaciones con el mismo mejor individio 505
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1202
# Contador de generaciones con el mismo mejor individio 506
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1203
# Contador de generaciones con el mismo mejor individio 507
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1204
# Contador de generaciones con el mismo mejor individio 508
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1205
# Contador de generaciones con el mismo mejor individio 509
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1206
# Contador de generaciones con el mismo mejor individio 510
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1207
# Contador de generaciones con el mismo mejor individio 511
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1208
# Contador de generaciones con el mismo mejor individio 512
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1209
# Contador de generaciones con el mismo mejor individio 513
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1210
# Contador de generaciones con el mismo mejor individio 514
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1211
# Contador de generaciones con el mismo mejor individio 515
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1212
# Contador de generaciones con el mismo mejor individio 516
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1213
# Contador de generaciones con el mismo mejor individio 517
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1214
# Contador de generaciones con el mismo mejor individio 518
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1215
# Contador de generaciones con el mismo mejor individio 519
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1216
# Contador de generaciones con el mismo mejor individio 520
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1217
# Contador de generaciones con el mismo mejor individio 521
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1218
# Contador de generaciones con el mismo mejor individio 522
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1219
# Contador de generaciones con el mismo mejor individio 523
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1220
# Contador de generaciones con el mismo mejor individio 524
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1221
# Contador de generaciones con el mismo mejor individio 525
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1222
# Contador de generaciones con el mismo mejor individio 526
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1223
# Contador de generaciones con el mismo mejor individio 527
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1224
# Contador de generaciones con el mismo mejor individio 528
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1225
# Contador de generaciones con el mismo mejor individio 529
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1226
# Contador de generaciones con el mismo mejor individio 530
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1227
# Contador de generaciones con el mismo mejor individio 531
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1228
# Contador de generaciones con el mismo mejor individio 532
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1229
# Contador de generaciones con el mismo mejor individio 533
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1230
# Contador de generaciones con el mismo mejor individio 534
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1231
# Contador de generaciones con el mismo mejor individio 535
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1232
# Contador de generaciones con el mismo mejor individio 536
# Mejor solución actual: 8.0
# Mejor solución actual: 8.0
# mejor solucion [array([ 3, 20, 14,  4, 24, 16, 18, 12,  6, 13, 17, 11,  2, 25,  8,  9, 10,
#        22, 23,  1, 21,  5, 15,  7, 19], dtype=uint32), 8.0]
# --------------------------------
# No. de Generacion=
# 1233
# Contador de generaciones con el mismo mejor individio 537
# Mejor solución actual: 8.0
